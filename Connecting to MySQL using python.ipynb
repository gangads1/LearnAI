# %%
import pandas as pd

# %%
df1 = pd.read_csv('../data/data_1.csv')
df2 = pd.read_csv('../data/data_2_2.csv')
df3 = pd.read_csv('../data/data_3.csv')
df4 = pd.read_csv('../data/data_4_2.csv')

# %%
df1.head()
# Out:
#    Id  PetalLengthCm  PetalWidthCm
# 0   1            1.4           0.2
# 1   2            1.4           0.2
# 2   3            1.3           0.2
# 3   4            1.5           0.2
# 4   5            1.4           0.2

# %%
df2.head()
# Out:
#    Id  SepalLengthCm    SepalWidthCm
# 0   1            5.1  Three dot Five
# 1   2            4.9             3.5
# 2   3            4.7          3.Five
# 3   4            4.6               3
# 4   5            5.0               3

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 3.6+ KB

# %%
df3.head()
# Out:
#    Id          Species
# 0  51  Iris-versicolor
# 1  52  Iris-versicolor
# 2  53  Iris-versicolor
# 3  54  Iris-versicolor
# 4  55  Iris-versicolor

# %%
df4.head()
# Out:
#    Id  PetalLengthCm  PetalWidthCm      Species
# 0   1            1.4           0.2  Iris-setosa
# 1   2            1.4           0.2  iris-setosa
# 2   3            1.3           0.2  IRIS-SETOSA
# 3   4            1.5           0.2   IRISsetosa
# 4   5            1.4           0.2  IRIS_SETOSA

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             50 non-null     int64
#  1   PetalLengthCm  50 non-null     float64
#  2   PetalWidthCm   50 non-null     float64
#  3   Species        49 non-null     object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 1.7+ KB

# %%
df4.shape
# Out:
# (50, 4)

# %% [markdown]
# ### SQL connection

# %%
import mysql.connector as mysql
from mysql.connector import Error
try:
    conn = mysql.connect(host='localhost', user='root', password='root')
    
    if conn.is_connected():
        cursor = conn.cursor()
        
        cursor.execute("CREATE DATABASE iris")
        print("Database is created")
        
except Error as e:
    print("Error while connecting to MySql", e)
# Out:
# Error while connecting to MySql 1007 (HY000): Can't create database 'iris'; database exists

# %% [markdown]
# ### Table creation and values insertion

# %%
import mysql.connector as mysql
from mysql.connector import Error
try:
    conn = mysql.connect(host='localhost', database='iris', user='root', password='root') # tips
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS d1;') # tips_data
        print('Creating table....')
# in the below line please pass the create table statement which you want #to create
#tips_data(columnname1 datatype,columnname2 datatype .....)
        cursor.execute("CREATE TABLE d1(Id INT,PetalLengthCm FLOAT, PetalWidthCm FLOAT)")
        print("Table is created....")
        #loop through the data frame
        for i,row in df1.iterrows():
            #here %S means string values 
            # tips.tips_data
            sql = "INSERT INTO iris.d1 VALUES (%s,%s,%s)" # how many columns are there that many %s
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('iris',)
# Creating table....
# Table is created....
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted

# %% [markdown]
# ### check table d1 data from sql

# %%
sql  = "SELECT * FROM iris.d1"
cursor.execute(sql)
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# (1, 1.4, 0.2)
# (2, 1.4, 0.2)
# (3, 1.3, 0.2)
# (4, 1.5, 0.2)
# (5, 1.4, 0.2)
# (6, 1.7, 0.4)
# (7, 1.4, 0.3)
# (8, 1.5, 0.2)
# (9, 1.4, 0.2)
# (10, 1.5, 0.1)
# (11, 1.5, 0.2)
# (12, 1.6, 0.2)
# (13, 1.4, 0.1)
# (14, 1.1, 0.1)
# (15, 1.2, 0.2)
# (16, 1.5, 0.4)
# (17, 1.3, 0.4)
# (18, 1.4, 0.3)
# (19, 1.7, 0.3)
# (20, 1.5, 0.3)
# (21, 1.7, 0.2)
# (22, 1.5, 0.4)
# (23, 1.0, 0.2)
# (24, 1.7, 0.5)
# (25, 1.9, 0.2)
# (26, 1.6, 0.2)
# (27, 1.6, 0.4)
# (28, 1.5, 0.2)
# (29, 1.4, 0.2)
# (30, 1.6, 0.2)
# (31, 1.6, 0.2)
# (32, 1.5, 0.4)
# (33, 1.5, 0.1)
# (34, 1.4, 0.2)
# (35, 1.5, 0.1)
# (36, 1.2, 0.2)
# (37, 1.3, 0.2)
# (38, 1.5, 0.1)
# (39, 1.3, 0.2)
# (40, 1.5, 0.2)
# (41, 1.3, 0.3)
# (42, 1.3, 0.3)
# (43, 1.3, 0.2)
# (44, 1.6, 0.6)
# (45, 1.9, 0.4)
# (46, 1.4, 0.3)
# (47, 1.6, 0.2)
# (48, 1.4, 0.2)
# (49, 1.5, 0.2)
# (50, 1.4, 0.2)
# (51, 4.7, 1.4)
# (52, 4.5, 1.5)
# (53, 4.9, 1.5)
# (54, 4.0, 1.3)
# (55, 4.6, 1.5)
# (56, 4.5, 1.3)
# (57, 4.7, 1.6)
# (58, 3.3, 1.0)
# (59, 4.6, 1.3)
# (60, 3.9, 1.4)
# (61, 3.5, 1.0)
# (62, 4.2, 1.5)
# (63, 4.0, 1.0)
# (64, 4.7, 1.4)
# (65, 3.6, 1.3)
# (66, 4.4, 1.4)
# (67, 4.5, 1.5)
# (68, 4.1, 1.0)
# (69, 4.5, 1.5)
# (70, 3.9, 1.1)
# (71, 4.8, 1.8)
# (72, 4.0, 1.3)
# (73, 4.9, 1.5)
# (74, 4.7, 1.2)
# (75, 4.3, 1.3)
# (76, 4.4, 1.4)
# (77, 4.8, 1.4)
# (78, 5.0, 1.7)
# (79, 4.5, 1.5)
# (80, 3.5, 1.0)
# (81, 3.8, 1.1)
# (82, 3.7, 1.0)
# (83, 3.9, 1.2)
# (84, 5.1, 1.6)
# (85, 4.5, 1.5)
# (86, 4.5, 1.6)
# (87, 4.7, 1.5)
# (88, 4.4, 1.3)
# (89, 4.1, 1.3)
# (90, 4.0, 1.3)
# (91, 4.4, 1.2)
# (92, 4.6, 1.4)
# (93, 4.0, 1.2)
# (94, 3.3, 1.0)
# (95, 4.2, 1.3)
# (96, 4.2, 1.2)
# (97, 4.2, 1.3)
# (98, 4.3, 1.3)
# (99, 3.0, 1.1)
# (100, 4.1, 1.3)
# (101, 6.0, 2.5)
# (102, 5.1, 1.9)
# (103, 5.9, 2.1)
# (104, 5.6, 1.8)
# (105, 5.8, 2.2)
# (106, 6.6, 2.1)
# (107, 4.5, 1.7)
# (108, 6.3, 1.8)
# (109, 5.8, 1.8)
# (110, 6.1, 2.5)
# (111, 5.1, 2.0)
# (112, 5.3, 1.9)
# (113, 5.5, 2.1)
# (114, 5.0, 2.0)
# (115, 5.1, 2.4)
# (116, 5.3, 2.3)
# (117, 5.5, 1.8)
# (118, 6.7, 2.2)
# (119, 6.9, 2.3)
# (120, 5.0, 1.5)
# (121, 5.7, 2.3)
# (122, 4.9, 2.0)
# (123, 6.7, 2.0)
# (124, 4.9, 1.8)
# (125, 5.7, 2.1)
# (126, 6.0, 1.8)
# (127, 4.8, 1.8)
# (128, 4.9, 1.8)
# (129, 5.6, 2.1)
# (130, 5.8, 1.6)
# (131, 6.1, 1.9)
# (132, 6.4, 2.0)
# (133, 5.6, 2.2)
# (134, 5.1, 1.5)
# (135, 5.6, 1.4)
# (136, 6.1, 2.3)
# (137, 5.6, 2.4)
# (138, 5.5, 1.8)
# (139, 4.8, 1.8)
# (140, 5.4, 2.1)
# (141, 5.6, 2.4)
# (142, 5.1, 2.3)
# (143, 5.1, 1.9)
# (144, 5.9, 2.3)
# (145, 5.7, 2.5)
# (146, 5.2, 2.3)
# (147, 5.0, 1.9)
# (148, 5.2, 2.0)
# (149, 5.4, 2.3)
# (150, 5.1, 1.8)

# %%
import warnings
warnings.filterwarnings(action='ignore')

data_1 = pd.read_sql("SELECT * From iris.d1", conn)
data_1
# Out:
#       Id  PetalLengthCm  PetalWidthCm
# 0      1            1.4           0.2
# 1      2            1.4           0.2
# 2      3            1.3           0.2
# 3      4            1.5           0.2
# 4      5            1.4           0.2
# ..   ...            ...           ...
# 145  146            5.2           2.3
# 146  147            5.0           1.9
# 147  148            5.2           2.0
# 148  149            5.4           2.3
# 149  150            5.1           1.8
#
# [150 rows x 3 columns]

# %% [markdown]
# ### Table_2 creation

# %%
import mysql.connector as mysql
from mysql.connector import Error
try:
    conn = mysql.connect(host='localhost', database='iris', user='root', password='root') # tips
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS d2;') # tips_data
        print('Creating table....')
# in the below line please pass the create table statement which you want #to create
#tips_data(columnname1 datatype,columnname2 datatype .....)
        cursor.execute("CREATE TABLE d2(Id INT,SepalLengthCm FLOAT, SepalWidthCm VARCHAR(200))")
        print("Table is created....")
        #loop through the data frame
        for i,row in df2.iterrows():
            #here %S means string values 
            # tips.tips_data
            sql = "INSERT INTO iris.d2 VALUES (%s,%s,%s)" # how many columns are there that many %s
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('iris',)
# Creating table....
# Table is created....
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted

# %% [markdown]
# ### check table d2 data from sql

# %%
sql  = "SELECT * FROM iris.d2"
cursor.execute(sql)
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# (1, 5.1, 'Three dot Five')
# (2, 4.9, '3.5')
# (3, 4.7, '3.Five')
# (4, 4.6, '3')
# (5, 5.0, '3')
# (6, 5.4, 'Three')
# (7, 4.6, 'Three.five')
# (8, 5.0, 'THREE Five')
# (9, 4.4, '3.$')
# (10, 4.9, '3.1')
# (11, 5.4, '3.7')
# (12, 4.8, '3.4')
# (13, 4.8, '3')
# (14, 4.3, '3')
# (15, 5.8, '4')
# (16, 5.7, '4.4')
# (17, 5.4, '3.9')
# (18, 5.1, '3.5')
# (19, 5.7, '3.8')
# (20, 5.1, '3.8')
# (21, 5.4, '3.4')
# (22, 5.1, '3.7')
# (23, 4.6, '3.6')
# (24, 5.1, '3.3')
# (25, 4.8, '3.4')
# (26, 5.0, '3')
# (27, 5.0, '3.4')
# (28, 5.2, '3.5')
# (29, 5.2, '3.4')
# (30, 4.7, '3.2')
# (31, 4.8, '3.1')
# (32, 5.4, '3.4')
# (33, 5.2, '4.1')
# (34, 5.5, '4.2')
# (35, 4.9, '3.1')
# (36, 5.0, '3.2')
# (37, 5.5, '3.5')
# (38, 4.9, '3.1')
# (39, 4.4, '3')
# (40, 5.1, '3.4')
# (41, 5.0, '3.5')
# (42, 4.5, '2.3')
# (43, 4.4, '3.2')
# (44, 5.0, '3.5')
# (45, 5.1, '3.8')
# (46, 4.8, '3')
# (47, 5.1, '3.8')
# (48, 4.6, '3.2')
# (49, 5.3, '3.7')
# (50, 5.0, '3.3')
# (51, 7.0, '3.2')
# (52, 6.4, '3.2')
# (53, 6.9, '3.1')
# (54, 5.5, '2.3')
# (55, 6.5, '2.8')
# (56, 5.7, '2.8')
# (57, 6.3, '3.3')
# (58, 4.9, '2.4')
# (59, 6.6, '2.9')
# (60, 5.2, '2.7')
# (61, 5.0, '2')
# (62, 5.9, '3')
# (63, 6.0, '2.2')
# (64, 6.1, '2.9')
# (65, 5.6, '2.9')
# (66, 6.7, '3.1')
# (67, 5.6, '3')
# (68, 5.8, '2.7')
# (69, 6.2, '2.2')
# (70, 5.6, '2.5')
# (71, 5.9, '3.2')
# (72, 6.1, '2.8')
# (73, 6.3, '2.5')
# (74, 6.1, '2.8')
# (75, 6.4, '2.9')
# (76, 6.6, '3')
# (77, 6.8, '2.8')
# (78, 6.7, '3')
# (79, 6.0, '2.9')
# (80, 5.7, '2.6')
# (81, 5.5, '2.4')
# (82, 5.5, '2.4')
# (83, 5.8, '2.7')
# (84, 6.0, '2.7')
# (85, 5.4, '3')
# (86, 6.0, '3.4')
# (87, 6.7, '3.1')
# (88, 6.3, '2.3')
# (89, 5.6, '3')
# (90, 5.5, '2.5')
# (91, 5.5, '2.6')
# (92, 6.1, '3')
# (93, 5.8, '2.6')
# (94, 5.0, '2.3')
# (95, 5.6, '2.7')
# (96, 5.7, '3')
# (97, 5.7, '2.9')
# (98, 6.2, '2.9')
# (99, 5.1, '2.5')
# (100, 5.7, '2.8')
# (101, 6.3, '3.3')
# (102, 5.8, '2.7')
# (103, 7.1, '3')
# (104, 6.3, '2.9')
# (105, 6.5, '3')
# (106, 7.6, '3')
# (107, 4.9, '2.5')
# (108, 7.3, '2.9')
# (109, 6.7, '2.5')
# (110, 7.2, '3.6')
# (111, 6.5, '3.2')
# (112, 6.4, '2.7')
# (113, 6.8, '3')
# (114, 5.7, '2.5')
# (115, 5.8, '2.8')
# (116, 6.4, '3.2')
# (117, 6.5, '3')
# (118, 7.7, '3.8')
# (119, 7.7, '2.6')
# (120, 6.0, '2.2')
# (121, 6.9, '3.2')
# (122, 5.6, '2.8')
# (123, 7.7, '2.8')
# (124, 6.3, '2.7')
# (125, 6.7, '3.3')
# (126, 7.2, '3.2')
# (127, 6.2, '2.8')
# (128, 6.1, '3')
# (129, 6.4, '2.8')
# (130, 7.2, '3')
# (131, 7.4, '2.8')
# (132, 7.9, '3.8')
# (133, 6.4, '2.8')
# (134, 6.3, '2.8')
# (135, 6.1, '2.6')
# (136, 7.7, '3')
# (137, 6.3, '3.4')
# (138, 6.4, '3.1')
# (139, 6.0, '3')
# (140, 6.9, '3.1')
# (141, 6.7, '3.1')
# (142, 6.9, '3.1')
# (143, 5.8, '2.7')
# (144, 6.8, '3.2')
# (145, 6.7, '3.3')
# (146, 6.7, '3')
# (147, 6.3, '2.5')
# (148, 6.5, '3')
# (149, 6.2, '3.4')
# (150, 5.9, '3')

# %% [markdown]
# ### create dataframe using sql database

# %%
data_2 = pd.read_sql("SELECT * From iris.d2", conn)
data_2
# Out:
#       Id  SepalLengthCm    SepalWidthCm
# 0      1            5.1  Three dot Five
# 1      2            4.9             3.5
# 2      3            4.7          3.Five
# 3      4            4.6               3
# 4      5            5.0               3
# ..   ...            ...             ...
# 145  146            6.7               3
# 146  147            6.3             2.5
# 147  148            6.5               3
# 148  149            6.2             3.4
# 149  150            5.9               3
#
# [150 rows x 3 columns]

# %% [markdown]
# ### Table_3 Creation

# %%
import mysql.connector as mysql
from mysql.connector import Error
try:
    conn = mysql.connect(host='localhost', database='iris', user='root', password='root') # tips
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS d3;') # tips_data
        print('Creating table....')
# in the below line please pass the create table statement which you want #to create
#tips_data(columnname1 datatype,columnname2 datatype .....)
        cursor.execute("CREATE TABLE d3(Id INT,Species VARCHAR(200))")
        print("Table is created....")
        #loop through the data frame
        for i,row in df3.iterrows():
            #here %S means string values 
            # tips.tips_data
            sql = "INSERT INTO iris.d3 VALUES (%s,%s)" # how many columns are there that many %s
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('iris',)
# Creating table....
# Table is created....
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted

# %% [markdown]
# ### check table d3 data from SQL

# %%
sql  = "SELECT * FROM iris.d3"
cursor.execute(sql)
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# (51, 'Iris-versicolor')
# (52, 'Iris-versicolor')
# (53, 'Iris-versicolor')
# (54, 'Iris-versicolor')
# (55, 'Iris-versicolor')
# (56, 'Iris-versicolor')
# (57, 'Iris-versicolor')
# (58, 'Iris-versicolor')
# (59, 'Iris-versicolor')
# (60, 'Iris-versicolor')
# (61, 'Iris-versicolor')
# (62, 'Iris-versicolor')
# (63, 'Iris-versicolor')
# (64, 'Iris-versicolor')
# (65, 'Iris-versicolor')
# (66, 'Iris-versicolor')
# (67, 'Iris-versicolor')
# (68, 'Iris-versicolor')
# (69, 'Iris-versicolor')
# (70, 'Iris-versicolor')
# (71, 'Iris-versicolor')
# (72, 'Iris-versicolor')
# (73, 'Iris-versicolor')
# (74, 'Iris-versicolor')
# (75, 'Iris-versicolor')
# (76, 'Iris-versicolor')
# (77, 'Iris-versicolor')
# (78, 'Iris-versicolor')
# (79, 'Iris-versicolor')
# (80, 'Iris-versicolor')
# (81, 'Iris-versicolor')
# (82, 'Iris-versicolor')
# (83, 'Iris-versicolor')
# (84, 'Iris-versicolor')
# (85, 'Iris-versicolor')
# (86, 'Iris-versicolor')
# (87, 'Iris-versicolor')
# (88, 'Iris-versicolor')
# (89, 'Iris-versicolor')
# (90, 'Iris-versicolor')
# (91, 'Iris-versicolor')
# (92, 'Iris-versicolor')
# (93, 'Iris-versicolor')
# (94, 'Iris-versicolor')
# (95, 'Iris-versicolor')
# (96, 'Iris-versicolor')
# (97, 'Iris-versicolor')
# (98, 'Iris-versicolor')
# (99, 'Iris-versicolor')
# (100, 'Iris-versicolor')
# (101, 'Iris-virginica')
# (102, 'Iris-virginica')
# (103, 'Iris-virginica')
# (104, 'Iris-virginica')
# (105, 'Iris-virginica')
# (106, 'Iris-virginica')
# (107, 'Iris-virginica')
# (108, 'Iris-virginica')
# (109, 'Iris-virginica')
# (110, 'Iris-virginica')
# (111, 'Iris-virginica')
# (112, 'Iris-virginica')
# (113, 'Iris-virginica')
# (114, 'Iris-virginica')
# (115, 'Iris-virginica')
# (116, 'Iris-virginica')
# (117, 'Iris-virginica')
# (118, 'Iris-virginica')
# (119, 'Iris-virginica')
# (120, 'Iris-virginica')
# (121, 'Iris-virginica')
# (122, 'Iris-virginica')
# (123, 'Iris-virginica')
# (124, 'Iris-virginica')
# (125, 'Iris-virginica')
# (126, 'Iris-virginica')
# (127, 'Iris-virginica')
# (128, 'Iris-virginica')
# (129, 'Iris-virginica')
# (130, 'Iris-virginica')
# (131, 'Iris-virginica')
# (132, 'Iris-virginica')
# (133, 'Iris-virginica')
# (134, 'Iris-virginica')
# (135, 'Iris-virginica')
# (136, 'Iris-virginica')
# (137, 'Iris-virginica')
# (138, 'Iris-virginica')
# (139, 'Iris-virginica')
# (140, 'Iris-virginica')
# (141, 'Iris-virginica')
# (142, 'Iris-virginica')
# (143, 'Iris-virginica')
# (144, 'Iris-virginica')
# (145, 'Iris-virginica')
# (146, 'Iris-virginica')
# (147, 'Iris-virginica')
# (148, 'Iris-virginica')
# (149, 'Iris-virginica')
# (150, 'Iris-virginica')

# %% [markdown]
# ### create dataframe using sql database

# %%
data_3 = pd.read_sql("SELECT * From iris.d3", conn)
data_3
# Out:
#      Id          Species
# 0    51  Iris-versicolor
# 1    52  Iris-versicolor
# 2    53  Iris-versicolor
# 3    54  Iris-versicolor
# 4    55  Iris-versicolor
# ..  ...              ...
# 95  146   Iris-virginica
# 96  147   Iris-virginica
# 97  148   Iris-virginica
# 98  149   Iris-virginica
# 99  150   Iris-virginica
#
# [100 rows x 2 columns]

# %%
df4
# Out:
#     Id  PetalLengthCm  PetalWidthCm      Species
# 0    1            1.4           0.2  Iris-setosa
# 1    2            1.4           0.2  iris-setosa
# 2    3            1.3           0.2  IRIS-SETOSA
# 3    4            1.5           0.2   IRISsetosa
# 4    5            1.4           0.2  IRIS_SETOSA
# 5    6            1.7           0.4   irisSetosa
# 6    7            1.4           0.3   IrisSetosa
# 7    8            1.5           0.2  iris-setosa
# 8    9            1.4           0.2  iri$-$eto$a
# 9   10            1.5           0.1   irisSETOSA
# 10  11            1.5           0.2          NaN
# 11  12            1.6           0.2  Iris-setesa
# 12  13            1.4           0.1       setosa
# 13  14            1.1           0.1       Setosa
# 14  15            1.2           0.2       SETOSA
# 15  16            1.5           0.4       $e+osa
# 16  17            1.3           0.4  Iris-setosa
# 17  18            1.4           0.3  Iris-setosa
# 18  19            1.7           0.3  Iris-setosa
# 19  20            1.5           0.3  Iris-setosa
# 20  21            1.7           0.2  Iris-setosa
# 21  22            1.5           0.4  Iris-setosa
# 22  23            1.0           0.2  Iris-setosa
# 23  24            1.7           0.5  Iris-setosa
# 24  25            1.9           0.2  Iris-setosa
# 25  26            1.6           0.2  Iris-setosa
# 26  27            1.6           0.4  Iris-setosa
# 27  28            1.5           0.2  Iris-setosa
# 28  29            1.4           0.2  Iris-setosa
# 29  30            1.6           0.2  Iris-setosa
# 30  31            1.6           0.2  Iris-setosa
# 31  32            1.5           0.4  Iris-setosa
# 32  33            1.5           0.1  Iris-setosa
# 33  34            1.4           0.2  Iris-setosa
# 34  35            1.5           0.1  Iris-setosa
# 35  36            1.2           0.2  Iris-setosa
# 36  37            1.3           0.2  Iris-setosa
# 37  38            1.5           0.1  Iris-setosa
# 38  39            1.3           0.2  Iris-setosa
# 39  40            1.5           0.2  Iris-setosa
# 40  41            1.3           0.3  Iris-setosa
# 41  42            1.3           0.3  Iris-setosa
# 42  43            1.3           0.2  Iris-setosa
# 43  44            1.6           0.6  Iris-setosa
# 44  45            1.9           0.4  Iris-setosa
# 45  46            1.4           0.3  Iris-setosa
# 46  47            1.6           0.2  Iris-setosa
# 47  48            1.4           0.2  Iris-setosa
# 48  49            1.5           0.2  Iris-setosa
# 49  50            1.4           0.2  Iris-setosa

# %%
import numpy as np
df4.replace(np.nan, None, inplace=True)

# %% [markdown]
# ### Table_4 Creation

# %%
import mysql.connector as mysql
from mysql.connector import Error
try:
    conn = mysql.connect(host='localhost', database='iris', user='root', password='root') # tips
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS d4;') # tips_data
        print('Creating table....')
# in the below line please pass the create table statement which you want #to create
#tips_data(columnname1 datatype,columnname2 datatype .....)
        cursor.execute("CREATE TABLE d4(Id INT,PetalLengthCm FLOAT, PetalWidthCm FLOAT, Species VARCHAR(200))")
        print("Table is created....")
        #loop through the data frame
        for i,row in df4.iterrows():
            #here %S means string values 
            # tips.tips_data
            sql = "INSERT INTO iris.d4 VALUES (%s,%s,%s,%s)" # how many columns are there that many %s
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('iris',)
# Creating table....
# Table is created....
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted

# %% [markdown]
# ### check table d4 data from SQL

# %%
sql  = "SELECT * FROM iris.d4"
cursor.execute(sql)
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# (1, 1.4, 0.2, 'Iris-setosa')
# (2, 1.4, 0.2, 'iris-setosa')
# (3, 1.3, 0.2, 'IRIS-SETOSA')
# (4, 1.5, 0.2, 'IRISsetosa')
# (5, 1.4, 0.2, 'IRIS_SETOSA')
# (6, 1.7, 0.4, 'irisSetosa')
# (7, 1.4, 0.3, 'IrisSetosa')
# (8, 1.5, 0.2, 'iris-setosa')
# (9, 1.4, 0.2, 'iri$-$eto$a')
# (10, 1.5, 0.1, 'irisSETOSA')
# (11, 1.5, 0.2, None)
# (12, 1.6, 0.2, 'Iris-setesa')
# (13, 1.4, 0.1, 'setosa')
# (14, 1.1, 0.1, 'Setosa')
# (15, 1.2, 0.2, 'SETOSA')
# (16, 1.5, 0.4, '$e+osa')
# (17, 1.3, 0.4, 'Iris-setosa')
# (18, 1.4, 0.3, 'Iris-setosa')
# (19, 1.7, 0.3, 'Iris-setosa')
# (20, 1.5, 0.3, 'Iris-setosa')
# (21, 1.7, 0.2, 'Iris-setosa')
# (22, 1.5, 0.4, 'Iris-setosa')
# (23, 1.0, 0.2, 'Iris-setosa')
# (24, 1.7, 0.5, 'Iris-setosa')
# (25, 1.9, 0.2, 'Iris-setosa')
# (26, 1.6, 0.2, 'Iris-setosa')
# (27, 1.6, 0.4, 'Iris-setosa')
# (28, 1.5, 0.2, 'Iris-setosa')
# (29, 1.4, 0.2, 'Iris-setosa')
# (30, 1.6, 0.2, 'Iris-setosa')
# (31, 1.6, 0.2, 'Iris-setosa')
# (32, 1.5, 0.4, 'Iris-setosa')
# (33, 1.5, 0.1, 'Iris-setosa')
# (34, 1.4, 0.2, 'Iris-setosa')
# (35, 1.5, 0.1, 'Iris-setosa')
# (36, 1.2, 0.2, 'Iris-setosa')
# (37, 1.3, 0.2, 'Iris-setosa')
# (38, 1.5, 0.1, 'Iris-setosa')
# (39, 1.3, 0.2, 'Iris-setosa')
# (40, 1.5, 0.2, 'Iris-setosa')
# (41, 1.3, 0.3, 'Iris-setosa')
# (42, 1.3, 0.3, 'Iris-setosa')
# (43, 1.3, 0.2, 'Iris-setosa')
# (44, 1.6, 0.6, 'Iris-setosa')
# (45, 1.9, 0.4, 'Iris-setosa')
# (46, 1.4, 0.3, 'Iris-setosa')
# (47, 1.6, 0.2, 'Iris-setosa')
# (48, 1.4, 0.2, 'Iris-setosa')
# (49, 1.5, 0.2, 'Iris-setosa')
# (50, 1.4, 0.2, 'Iris-setosa')

# %% [markdown]
# ### create dataframe using sql database

# %%
import warnings
warnings.filterwarnings(action='ignore')

data_4 = pd.read_sql("SELECT * From iris.d4", conn)
data_4
# Out:
#     Id  PetalLengthCm  PetalWidthCm      Species
# 0    1            1.4           0.2  Iris-setosa
# 1    2            1.4           0.2  iris-setosa
# 2    3            1.3           0.2  IRIS-SETOSA
# 3    4            1.5           0.2   IRISsetosa
# 4    5            1.4           0.2  IRIS_SETOSA
# 5    6            1.7           0.4   irisSetosa
# 6    7            1.4           0.3   IrisSetosa
# 7    8            1.5           0.2  iris-setosa
# 8    9            1.4           0.2  iri$-$eto$a
# 9   10            1.5           0.1   irisSETOSA
# 10  11            1.5           0.2         None
# 11  12            1.6           0.2  Iris-setesa
# 12  13            1.4           0.1       setosa
# 13  14            1.1           0.1       Setosa
# 14  15            1.2           0.2       SETOSA
# 15  16            1.5           0.4       $e+osa
# 16  17            1.3           0.4  Iris-setosa
# 17  18            1.4           0.3  Iris-setosa
# 18  19            1.7           0.3  Iris-setosa
# 19  20            1.5           0.3  Iris-setosa
# 20  21            1.7           0.2  Iris-setosa
# 21  22            1.5           0.4  Iris-setosa
# 22  23            1.0           0.2  Iris-setosa
# 23  24            1.7           0.5  Iris-setosa
# 24  25            1.9           0.2  Iris-setosa
# 25  26            1.6           0.2  Iris-setosa
# 26  27            1.6           0.4  Iris-setosa
# 27  28            1.5           0.2  Iris-setosa
# 28  29            1.4           0.2  Iris-setosa
# 29  30            1.6           0.2  Iris-setosa
# 30  31            1.6           0.2  Iris-setosa
# 31  32            1.5           0.4  Iris-setosa
# 32  33            1.5           0.1  Iris-setosa
# 33  34            1.4           0.2  Iris-setosa
# 34  35            1.5           0.1  Iris-setosa
# 35  36            1.2           0.2  Iris-setosa
# 36  37            1.3           0.2  Iris-setosa
# 37  38            1.5           0.1  Iris-setosa
# 38  39            1.3           0.2  Iris-setosa
# 39  40            1.5           0.2  Iris-setosa
# 40  41            1.3           0.3  Iris-setosa
# 41  42            1.3           0.3  Iris-setosa
# 42  43            1.3           0.2  Iris-setosa
# 43  44            1.6           0.6  Iris-setosa
# 44  45            1.9           0.4  Iris-setosa
# 45  46            1.4           0.3  Iris-setosa
# 46  47            1.6           0.2  Iris-setosa
# 47  48            1.4           0.2  Iris-setosa
# 48  49            1.5           0.2  Iris-setosa
# 49  50            1.4           0.2  Iris-setosa
